# %%
import pandas as pd
from requests import get
from bs4 import BeautifulSoup
import requests
import googlemaps

# %%
html = requests.get('https://fr.wikipedia.org/wiki/Liste_des_communes_de_France_les_plus_peupl%C3%A9es').text
soup = BeautifulSoup(html)

# %%
dict = {}
for i in range (1,170,18):
    liste = []
    mot1 = soup.find_all('td')[i].find('a').attrs['title']
    mot2 = [i for i in soup.find_all('td')[i+3].strings][1].replace('\xa0', '')
    dict[mot1] = mot2
dict
# Out:
# {'Paris': '2190327',
#  'Marseille': '862211',
#  'Lyon': '515695',
#  'Toulouse': '475438',
#  'Nice': '342637',
#  'Nantes': '306694',
#  'Montpellier': '281613',
#  'Strasbourg': '279284',
#  'Bordeaux': '252040',
#  'Lille': '232440'}

# %%
villes = dict.keys()

# %%
def get_currency(a):
    url = 'http://www.geoplugin.net/json.gp?ip='+str(a)
    resp = requests.get(url)
    repos = resp.json()
    return repos['geoplugin_currencyCode']

# %%
print(get_currency('123.212.222.12'))
# Out:
# KRW

# %%
api_key = 'AIzaSyDH-JjGEPRYOzOIzrBC95ihb2Rf6vcfWEM'
gmaps = googlemaps.Client(key=api_key)

# %%
result = gmaps.distance_matrix(villes, villes)

# %%
result
# Out:
# {'destination_addresses': ['Paris, France',
#   'Marseille, France',
#   'Lyon, France',
#   'Toulouse, France',
#   'Nice, France',
#   'Nantes, France',
#   'Montpellier, France',
#   'Strasbourg, France',
#   'Bordeaux, France',
#   'Lille, France'],
#  'origin_addresses': ['Paris, France',
#   'Marseille, France',
#   'Lyon, France',
#   'Toulouse, France',
#   'Nice, France',
#   'Nantes, France',
#   'Montpellier, France',
#   'Strasbourg, France',
#   'Bordeaux, France',
#   'Lille, France'],
#  'rows': [{'elements': [{'distance': {'text': '1 m', 'value': 0},
#      'duration': {'text': '1 min', 'value': 0},
#      'status': 'OK'},
#     {'distance': {'text': '775 km', 'value': 774919},
#      'duration': {'text': '7 hours 17 mins', 'value': 26206},
#      'status': 'OK'},
#     {'distance': {'text': '466 km', 'value': 465611},
#      'duration': {'text': '4 hours 26 mins', 'value': 15945},
#      'status': 'OK'},
#     {'distance': {'text': '678 km', 'value': 678310},
# ...

# %%
#for j in range(0,10):
 #   for i in result['rows'][j]['elements']:
  #      print(i['distance']['text'])

matrix = [[i['distance']['text'] for i in result['rows'][j]['elements']] for j in range(0,10)]
df = pd.DataFrame(data = matrix, index=villes, columns=villes)
df
# Out:
#               Paris Marseille    Lyon Toulouse      Nice    Nantes  \
# Paris           1 m    775 km  466 km   678 km    932 km    385 km
# Marseille    775 km       1 m  314 km   403 km    199 km    986 km
# Lyon         466 km    315 km     1 m   538 km    472 km    686 km
# Toulouse     679 km    405 km  539 km      1 m    562 km    585 km
# Nice         932 km    199 km  471 km   560 km       1 m  1,143 km
# Nantes       385 km    986 km  685 km   585 km  1,143 km       1 m
# Montpellier  748 km    169 km  303 km   240 km    326 km    822 km
# Strasbourg   490 km    800 km  493 km   947 km    784 km    866 km
# Bordeaux     591 km    646 km  556 km   245 km    803 km    353 km
# Lille        225 km  1,001 km  692 km   894 km  1,158 km    601 km
#
#             Montpellier Strasbourg Bordeaux     Lille
# Paris            748 km     491 km   584 km    225 km
# Marseille        169 km     798 km   645 km  1,000 km
# Lyon             304 km     492 km   553 km    691 km
# ...
